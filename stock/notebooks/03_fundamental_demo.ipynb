# %% [markdown]
# # 03. ファンダメンタル分析デモ

# %%
from stockkit.analysis import fundamental

fundamental.snapshot_df(['AAPL','MSFT','NVDA','7203','9984'])

# %%
# 売上成長履歴
fundamental.revenue_growth_history('AAPL')
