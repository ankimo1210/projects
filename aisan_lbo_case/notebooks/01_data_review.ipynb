# %% [markdown]
# # Data Review
#
# Run the scripts in `src/fetch` and inspect generated CSVs in `data/processed`. This notebook is intentionally a lightweight placeholder so the repository remains reproducible from scripts.
