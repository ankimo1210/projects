# %% [markdown]
# # 10 portfolio construction
#
# **目的**: ポートフォリオ構築(risk parity/mean-variance、制約)
#
# > **Phase 2 スタブ**。データ層(01-03)が基盤。実装はプラットフォーム仕様の実装順(features → signals → models → backtest → tax → portfolio → dashboard → report)で進める。
#
# 前提リゴール: look-ahead 無し / マクロは `as_of` で release-date 厳守 / 複雑モデルは必ず単純ベースラインと比較 / 全標本でのパラメータ最適化をしない / 失敗戦略も報告。
